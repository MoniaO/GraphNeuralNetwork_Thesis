# %% [markdown]
# <a href="https://colab.research.google.com/github/MoniaO/GraphNeuralNetwork_Thesis/blob/develop/notebooks/train_setup_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Klonowanie środowiska git

# %%
# !git clone https://github.com/MoniaO/GraphNeuralNetwork_Thesis.git
# %cd GraphNeuralNetwork_Thesis
# !git checkout develop
# Out:
# Cloning into 'GraphNeuralNetwork_Thesis'...
# remote: Enumerating objects: 415, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 415 (delta 79), reused 88 (delta 37), pack-reused 275 (from 1)
# Receiving objects: 100% (415/415), 107.82 KiB | 4.31 MiB/s, done.
# Resolving deltas: 100% (206/206), done.
# /content/GraphNeuralNetwork_Thesis
# Branch 'develop' set up to track remote branch 'develop' from 'origin'.
# Switched to a new branch 'develop'

# %%
# !pip install wandb hydra-core omegaconf torch-geometric ogb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import os

# %%
import wandb
wandb.login(key="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")
#you can find your_key in W&B under User settings -> API key"
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: oskardmonika (politechnika-gnn-thesis) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.login(verify=True)
#additional verification of login - if everything's fine, it should return "True"
# Out:
# True

# %%
#!git checkout src/data/load_data.py

# %%
# !git pull origin develop
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 7 (delta 4), reused 7 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 625 bytes | 625.00 KiB/s, done.
# From https://github.com/MoniaO/GraphNeuralNetwork_Thesis
#  * branch            develop    -> FETCH_HEAD
#    28cf77c..64d84d4  develop    -> origin/develop
# Updating 28cf77c..64d84d4
# Fast-forward
#  configs/data/dataset_syn.yaml | 2 +-
#  src/train_lp.py               | 2 +-
#  2 files changed, 2 insertions(+), 2 deletions(-)

# %%
#run for ogb dataset
#!python src/train.py model=gcn data=ogb_dataset
# Out:
# data:
#   name: ogbl-ddi
#   task_type: link_prediction
#   metric: hits@20
#   root: data/
#   evaluator_type: ogb
# model:
#   name: gcn
#   hidden_dim: 64
#   num_layers: 3
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
# training:
#   lr: 0.001
#   epochs: 20
#   batch_size: 32
#   optimizer: adam
# wandb:
#   project: politechnika-gnn-thesis
#   entity: politechnika-gnn-thesis
#
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: oskardmonika (politechnika-gnn-thesis) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ setting up run dj92bl5t (0.0s)
# wandb: ⣻ setting up run dj92bl5t (0.0s)
# wandb: ⣽ setting up run dj92bl5t (0.0s)
# wandb: ⣾ setting up run dj92bl5t (0.0s)
# wandb: ⣷ setting up run dj92bl5t (0.5s)
# wandb: ⣯ setting up run dj92bl5t (0.5s)
# wandb: ⣟ setting up run dj92bl5t (0.5s)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#data in MyDrive, to test if it works for Shared Drive
import os
os.environ["PHARMA_DATA_ROOT"] = "/content/drive/MyDrive/synthetic_pharmacotherapy_v2 2/synthetic_pharmacotherapy_v2_1_nn_benchmark"

# %%
#single run (not multiple parameters, one target)
# !python src/train_lp.py model=gnn_lp model.conv_type=sage data=dataset_syn training.epochs=30
# Out:
# data:
#   name: syn
#   target:
#   - AKI
#   - DILI
#   - Depression
#   - Falls
#   - Delirium
#   - GI_bleeding
#   - Hyponatremia
#   - Hyperkalemia
#   - QT_arrhythmia
#   - Hospitalization
#   evaluator_type: synthetic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_1_edges_audited.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_no_overlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#       hidden: synthetic_pharmacotherapy_v2_samples_hidden_confounder.csv
#       doc: synthetic_pharmacotherapy_v2_samples_noisy_documentation.csv
#       bias: synthetic_pharmacotherapy_v2_samples_selection_bias.csv
#     scenario: clean
# model:
#   name: gnn_lp
#   conv_type: sage
#   hidden_dim: 64
#   num_layers: 3
#   dropout: 0.2
# ...

# %%
# !python src/train_lp.py model=gnn_lp model.conv_type=transformer data=dataset_syn training.epochs=30 data.target="Hospitalization"
# Out:
# data:
#   name: syn
#   target: Hospitalization
#   evaluator_type: synthetic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_1_edges_audited.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_no_overlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#       hidden: synthetic_pharmacotherapy_v2_samples_hidden_confounder.csv
#       doc: synthetic_pharmacotherapy_v2_samples_noisy_documentation.csv
#       bias: synthetic_pharmacotherapy_v2_samples_selection_bias.csv
#     scenario: clean
# model:
#   name: gnn_lp
#   conv_type: transformer
#   hidden_dim: 64
#   num_layers: 3
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
#   aggr: sum
#   heads: 4
# training:
#   lr: 0.001
#   epochs: 30
#   batch_size: 32
#   optimizer: adam
# ...

# %%
#multirun
# !python src/train.py --multirun model=gcn data=dataset_syn training.epochs=50 data.target="Hospitalization" model.num_layers=2,3,4,6,8,12
# Out:
# [2026-07-09 10:59:35,246][HYDRA] Launching 6 jobs locally
# [2026-07-09 10:59:35,247][HYDRA] 	#0 : model=gcn data=dataset_syn training.epochs=50 data.target=Hospitalization model.num_layers=2
# data:
#   name: syn
#   target: Hospitalization
#   evaluator_type: synthethic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_edges.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_nooverlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#     scenario: clean
# model:
#   name: gcn
#   hidden_dim: 64
#   num_layers: 2
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
# training:
#   lr: 0.001
#   epochs: 50
#   batch_size: 32
#   optimizer: adam
#   to_undirected: true
#   seed: 42
#   val_size: 0.1
#   test_size: 0.1
# meta:
# ...

# %%
#multirun gin
# !python src/train.py --multirun model=gin data=dataset_syn training.epochs=50 data.target="Hospitalization" model.num_layers=2,3,4,6
# Out:
# [2026-07-09 13:09:45,748][HYDRA] Launching 4 jobs locally
# [2026-07-09 13:09:45,748][HYDRA] 	#0 : model=gin data=dataset_syn training.epochs=50 data.target=Hospitalization model.num_layers=2
# data:
#   name: syn
#   target: Hospitalization
#   evaluator_type: synthetic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_edges.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_nooverlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#     scenario: clean
# model:
#   name: gin
#   hidden_dim: 64
#   num_layers: 2
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
# training:
#   lr: 0.001
#   epochs: 50
#   batch_size: 32
#   optimizer: adam
#   to_undirected: true
#   seed: 42
#   val_size: 0.1
#   test_size: 0.1
#   heads: 4
# ...

# %%
#multirun gat
# !python src/train.py --multirun model=gat data=dataset_syn training.epochs=50 data.target="Hospitalization" model.num_layers=2,4,6
# Out:
# [2026-07-09 13:21:23,984][HYDRA] Launching 3 jobs locally
# [2026-07-09 13:21:23,985][HYDRA] 	#0 : model=gat data=dataset_syn training.epochs=50 data.target=Hospitalization model.num_layers=2
# data:
#   name: syn
#   target: Hospitalization
#   evaluator_type: synthetic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_edges.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_nooverlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#     scenario: clean
# model:
#   name: gat
#   hidden_dim: 64
#   num_layers: 2
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
#   heads: 4
# training:
#   lr: 0.001
#   epochs: 50
#   batch_size: 32
#   optimizer: adam
#   to_undirected: true
#   seed: 42
#   val_size: 0.1
#   test_size: 0.1
#   heads: 4
# ...

# %%
#multirun sage
# !python src/train.py --multirun meta.owner_initials="MO" model=sage data=dataset_syn training.epochs=50 data.target="Hospitalization" model.num_layers=2,4,6
# Out:
# [2026-07-09 13:28:56,636][HYDRA] Launching 3 jobs locally
# [2026-07-09 13:28:56,636][HYDRA] 	#0 : meta.owner_initials=MO model=sage data=dataset_syn training.epochs=50 data.target=Hospitalization model.num_layers=2
# data:
#   name: syn
#   target: Hospitalization
#   evaluator_type: synthetic_evaluator
#   dataset:
#     root_dir: ${oc.env:PHARMA_DATA_ROOT}
#     nodes_file: synthetic_pharmacotherapy_v2_nodes.csv
#     edges_file: synthetic_pharmacotherapy_v2_edges.csv
#     samples:
#       clean: synthetic_pharmacotherapy_v2_samples_clean.csv
#       nooverlap: synthetic_pharmacotherapy_v2_samples_nooverlap.csv
#       multihospital: synthetic_pharmacotherapy_v2_samples_multihospital.csv
#     scenario: clean
# model:
#   name: sage
#   hidden_dim: 64
#   num_layers: 2
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
# training:
#   lr: 0.001
#   epochs: 50
#   batch_size: 32
#   optimizer: adam
#   to_undirected: true
#   seed: 42
#   val_size: 0.1
#   test_size: 0.1
# ...

# %%
import sys
sys.path.insert(0, "/content/GraphNeuralNetwork_Thesis/src")

# %%
train = 0
test = 0
valid = 0

# %%
from omegaconf import OmegaConf
from data.load_split_benchmark_data import load_split_benchmark_data
from data.load_split_benchmark_data import build_combined_splits

cfg = OmegaConf.create({
    "data": {
        "name": "syn",
        "target": "DILI",
        "dataset": {
            "root_dir": "/content/drive/MyDrive/synthetic_pharmacotherapy_v2 2/synthetic_pharmacotherapy_v2_1_nn_benchmark",
            "nodes_file": "synthetic_pharmacotherapy_v2_nodes.csv",
            "edges_file": "synthetic_pharmacotherapy_v2_1_edges_audited.csv",
            "include_external_test": False,
            "keep_scenario": False,
            "scenarios": {
                "clean": "synthetic_pharmacotherapy_v2_samples_clean.csv",
                "no_overlap": "synthetic_pharmacotherapy_v2_samples_no_overlap.csv",
                "multihospital": "synthetic_pharmacotherapy_v2_samples_multihospital.csv",
                "hidden":   "synthetic_pharmacotherapy_v2_samples_hidden_confounder.csv",
                "doc": "synthetic_pharmacotherapy_v2_samples_noisy_documentation.csv",
                "bias": "synthetic_pharmacotherapy_v2_samples_selection_bias.csv"
            },
        }
    }
})

#train, valid, test = load_split_benchmark_data(cfg)
x,y,z,a=build_combined_splits(cfg)

# %%
import pandas as pd

# %%
clean=pd.read_csv("/content/drive/MyDrive/synthetic_pharmacotherapy_v2 2/synthetic_pharmacotherapy_v2_1_nn_benchmark/synthetic_pharmacotherapy_v2_samples_clean.csv")

# %%
nodes=pd.read_csv("/content/drive/MyDrive/synthetic_pharmacotherapy_v2 2/synthetic_pharmacotherapy_v2_1_nn_benchmark/synthetic_pharmacotherapy_v2_nodes.csv")

# %%
columns = clean.columns.tolist()

# %%
columns
# Out:
# ['patient_id',
#  'hospital_id',
#  'age',
#  'alcohol_use',
#  'baseline_alt_ast',
#  'baseline_egfr',
#  'baseline_mood_vulnerability',
#  'baseline_potassium',
#  'baseline_qt_risk',
#  'baseline_sodium',
#  'ckd',
#  'depression_history',
#  'diabetes',
#  'frailty',
#  'heart_failure',
#  'infection',
#  'liver_disease',
#  'monitoring_intensity',
#  'polypharmacy_burden',
#  'sex_female',
#  'unobserved_severity',
#  'acei_arb',
#  'aminoglycoside',
#  'antibiotic_hepatic_risk',
#  'anticholinergic',
#  'anticoagulant',
#  'antiplatelet',
#  'benzodiazepine',
#  'beta_blocker',
#  'contrast_agent',
#  'corticosteroid',
#  'diuretic',
#  'hepatotoxic_drug_A',
#  'herbal_exposure',
#  'nsaid',
#  'opioid',
#  'ppi',
#  'qt_prolonging_drug',
#  'snri',
#  'ssri',
#  'thiazide',
#  'valproate_like_drug',
#  'anticholinergic_burden',
#  'cardiac_repolarization_delay',
#  'cholestatic_pattern',
#  'cns_sedation',
#  'coagulation_impairment',
#  'electrolyte_disturbance',
# ...

# %%
nodes[nodes['node'].isin(columns)]
# Out:
#                             node          node_type              layer  \
# 0                            age    patient_context  1_patient_context
# 1                    alcohol_use    patient_context  1_patient_context
# 2               baseline_alt_ast    patient_context  1_patient_context
# 3                  baseline_egfr    patient_context  1_patient_context
# 4    baseline_mood_vulnerability    patient_context  1_patient_context
# ..                           ...                ...                ...
# 101                  GI_bleeding  clinical_endpoint        6_endpoints
# 102              Hospitalization  clinical_endpoint        6_endpoints
# 103                 Hyperkalemia  clinical_endpoint        6_endpoints
# 104                 Hyponatremia  clinical_endpoint        6_endpoints
# 105                QT_arrhythmia  clinical_endpoint        6_endpoints
#
#                                        description  base_prevalence  \
# ...

# %%
train['node_features']['value'].isna() == True
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 17870575    False
# 17870576    False
# 17870577    False
# 17870578    False
# 17870579    False
# Name: value, Length: 17870580, dtype: bool

# %%
import torch

# %%
import torch
import pandas as pd

# The original code expected `train` to be a torch_geometric.data.HeteroData object,
# where 'patient_id' and 'variable' would be node types and
# ('patient_id', 'has', 'variable') an edge type.
# However, `train` is a dictionary of pandas DataFrames.

# To check for NaNs and Infs in the relevant numeric columns of the DataFrames:

# Check 'node_features' DataFrame's 'value' column
if 'node_features' in train and 'value' in train['node_features'].columns:
    node_features_values = torch.tensor(train['node_features']['value'].values, dtype=torch.float32)
    print(f"Node features (all nodes): NaN presence: {torch.isnan(node_features_values).any()}, Inf presence: {torch.isinf(node_features_values).any()}")
else:
    print("Warning: 'node_features' or 'value' column not found in train dictionary.")

# Check 'feature_edges' DataFrame's 'value' column
if 'feature_edges' in train and 'value' in train['feature_edges'].columns:
    edge_attributes_values = torch.tensor(train['feature_edges']['value'].values, dtype=torch.float32)
    print(f"Edge attributes (all edges): NaN presence: {torch.isnan(edge_attributes_values).any()}, Inf presence: {torch.isinf(edge_attributes_values).any()}")
else:
    print("Warning: 'feature_edges' or 'value' column not found in train dictionary.")

# Note: 'patient_id' and 'variable' are not direct keys for node types in the current
# `train` dictionary structure, nor is `("patient_id", "has", "variable")` an edge type key.
# Out:
# Node features (all nodes): NaN presence: True, Inf presence: False
# Edge attributes (all edges): NaN presence: False, Inf presence: False

# %%
type(train)
# Out:
# dict

# %%
ENDPOINTS = [
    "AKI", "DILI", "Depression", "Falls", "Delirium",
    "GI_bleeding", "Hyponatremia", "Hyperkalemia",
    "QT_arrhythmia", "Hospitalization",
]

N_total = len(samples)
stats = []

for ep in ENDPOINTS:
    #if ep not in samples.columns:
    #    continue
    N_pos = samples[ep].sum()
    N_neg = N_total - N_pos
    prevalence = N_pos / N_total
    stats.append((ep, int(N_pos), int(N_neg), prevalence))

for ep, N_pos, N_neg, prev in stats:
    print(f"{ep}: pos={N_pos}, neg={N_neg}, prev={prev:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6879/3280447676.py in <cell line: 0>()
#      11     #if ep not in samples.columns:
#      12     #    continue
# ---> 13     N_pos = samples[ep].sum()
#      14     N_neg = N_total - N_pos
#      15     prevalence = N_pos / N_total
#
# KeyError: 'AKI'

# %%
import pandas as pd

ENDPOINTS = [
    "AKI", "DILI", "Depression", "Falls", "Delirium",
    "GI_bleeding", "Hyponatremia", "Hyperkalemia",
    "QT_arrhythmia", "Hospitalization",
]

# tylko endpointy
E = samples[ENDPOINTS].astype(int)

# macierz współwystępowania: liczba pacjentów z ep_i=1 i ep_j=1
coocc_counts = pd.DataFrame(index=ENDPOINTS, columns=ENDPOINTS, dtype=int)

for ep_i in ENDPOINTS:
    for ep_j in ENDPOINTS:
        coocc_counts.loc[ep_i, ep_j] = ((E[ep_i] == 1) & (E[ep_j] == 1)).sum()

print(coocc_counts)
# Out:
#                    AKI  DILI  Depression  Falls  Delirium  GI_bleeding  \
# AKI              225.0   3.0        12.0   18.0      11.0          3.0
# DILI               3.0  64.0         2.0    4.0       4.0          2.0
# Depression        12.0   2.0       258.0   18.0       9.0          4.0
# Falls             18.0   4.0        18.0  411.0      23.0          1.0
# Delirium          11.0   4.0         9.0   23.0     233.0          0.0
# GI_bleeding        3.0   2.0         4.0    1.0       0.0         58.0
# Hyponatremia       8.0   2.0        11.0   15.0       6.0          0.0
# Hyperkalemia       9.0   1.0         8.0   11.0       5.0          1.0
# QT_arrhythmia      1.0   0.0         0.0    3.0       2.0          0.0
# Hospitalization   61.0  22.0        39.0  106.0      74.0          6.0
#
#                  Hyponatremia  Hyperkalemia  QT_arrhythmia  Hospitalization
# AKI                       8.0           9.0            1.0             61.0
# ...
