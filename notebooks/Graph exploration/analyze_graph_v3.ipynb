# %% [markdown]
# # Przeniesione
#
# `analyze_graph_v3.ipynb` został **połączony** z:
#
# `v3_graph_diagnostics.ipynb`
#
# Używaj wyłącznie scalonego notebooka. Ten plik zostawiony jako przekierowanie,
# żeby stare linki nie gubiły kontekstu.
