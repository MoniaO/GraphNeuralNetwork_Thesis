# %% [markdown]
# <a href="https://colab.research.google.com/github/MoniaO/GraphNeuralNetwork_Thesis/blob/develop/train_setup_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Klonowanie środowiska git

# %%
# !git clone https://github.com/MoniaO/GraphNeuralNetwork_Thesis.git
# %cd GraphNeuralNetwork_Thesis
# !git checkout develop
# Out:
# fatal: destination path 'GraphNeuralNetwork_Thesis' already exists and is not an empty directory.
# /content/GraphNeuralNetwork_Thesis
# Already on 'develop'
# Your branch is up to date with 'origin/develop'.

# %%
# !pip install wandb hydra-core omegaconf torch-geometric ogb

# %%
import os

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: oskardmonika (politechnika-gnn-thesis) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
#!git checkout src/data/load_data.py
# Out:
# Updated 1 path from the index

# %%
# !git pull origin develop
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 359 bytes | 359.00 KiB/s, done.
# From https://github.com/MoniaO/GraphNeuralNetwork_Thesis
#  * branch            develop    -> FETCH_HEAD
#    9dce80b..623ba75  develop    -> origin/develop
# Updating 9dce80b..623ba75
# Fast-forward
#  src/train.py | 5 ++---
#  1 file changed, 2 insertions(+), 3 deletions(-)

# %%
# !python src/train.py model=gcn data=ogb_dataset training.epochs=3 training.batch_size=64
# Out:
# data:
#   name: ogbl-ddi
#   task_type: link_prediction
#   metric: hits@20
#   root: data/
# model:
#   name: gcn
#   hidden_dim: 64
#   num_layers: 3
#   dropout: 0.2
#   batch_norm: true
#   activation: relu
# training:
#   lr: 0.001
#   epochs: 3
#   batch_size: 64
#   optimizer: adam
# wandb:
#   project: politechnika-gnn-thesis
#   entity: politechnika-gnn-thesis
#
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: oskardmonika (politechnika-gnn-thesis) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/GraphNeuralNetwork_Thesis/wandb/run-20260630_213356-ay60v5yt
# wandb: Run `wandb offline` to turn off syncing.
# ...
